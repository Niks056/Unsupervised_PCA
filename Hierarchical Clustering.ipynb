# %% [markdown]
# # Hierarchical Clustering

# %% [markdown]
# * Agglomerative: This is a "bottom up" approach: each observation starts in its own cluster, and pairs of clusters are merged as one moves up the hierarchy.
# * Divisive: This is a "top down" approach: all observations start in one cluster, and splits are performed recursively as one moves down the hierarchy.

# %% [markdown]
# ### Raw Data Points ( Before Clustering _ )

# %% [markdown]
# ![data_points.png](attachment:data_points.png)

# %% [markdown]
# ### Data points after clustering

# %% [markdown]
# ![h_clusters.png](attachment:h_clusters.png)

# %% [markdown]
# # Method

# %% [markdown]
# * Consider each point as a cluster
# * Combine two nearest clusters ( points) to form single cluster
# * Represent new cluster as the centroid of the cluster
# * Combine the nearest cluster to form one bigger cluster
# * Repeat the process untill all points form into single cluster
# * Use dendrogram to figure out the optimal number of clusters

# %%
#import libararies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#import dataset
df=pd.read_csv("clustering_dataset.csv")

# %%
df.shape
# Out:
# (3000, 2)

# %%
df.head(3)
# Out:
#         var1       var2
# 0   2.072345  -3.241693
# 1  17.936710  15.784810
# 2   1.083576   7.319176

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 2 columns):
# var1    3000 non-null float64
# var2    3000 non-null float64
# dtypes: float64(2)
# memory usage: 47.0 KB

# %%
#create input variables
X=df.loc[:,:].values

# %%
#import libraries to plot dendrogram
import scipy.cluster.hierarchy as sch

# %%
#plot dedrogram to visualise the possbile number of clusters
dendrogram=sch.dendrogram(sch.linkage(X,method='ward'))

# %%
## Training entire data using Heirarchical Clustering
from sklearn.cluster import AgglomerativeClustering

# %%
hc=AgglomerativeClustering(n_clusters=3)

# %%
clusters=hc.fit(X)

# %%
clusters.labels_
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
#visualize the clusters  with labels
plt.scatter(X[:,0],X[:,1], c=clusters.labels_, cmap='rainbow')  
plt.show()

# %%
#increased number of clusters
hc=AgglomerativeClustering(n_clusters=5)

# %%
clusters=hc.fit(X)

# %%
#visualize the clusters  with labels
plt.scatter(X[:,0],X[:,1], c=clusters.labels_, cmap='rainbow')  
plt.show()

# %% [markdown]
# ## Key Points

# %% [markdown]
# 1.  K-Means can handle big data better than Hierarchichal Clustering
# 2.  Clusteing is senstive to the scale of the data , so also advisable to normalise it
# 3.  In buinsess cases , it helps to use domain knowledge for clustering
# 4.  Clustering before supervised learning also helps in better results
# 5.  K-Means is faster than Hierarchical clustering
